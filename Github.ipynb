# %% [markdown]
# ### NAME:- Arjya Keshari Biswal
#
# ### EMAIL ID:- ariyabiswal123@gmail.com
#
# ### DOMAIN:- Ds/AIML
#
# ### BATCH:- 15th April 2026 Batch
#
# ### GITHUB LINK:- https://github.com/ABiswal248/AITravelPlanner.git
